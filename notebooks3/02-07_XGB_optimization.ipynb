# %%
# import pathlib
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import re
#import random
#from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, roc_auc_score
from sklearn.preprocessing import QuantileTransformer
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

from sklearn.metrics import confusion_matrix
import xgboost as xgb
from sklearn.metrics import auc, accuracy_score, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV
#from string import ascii_letters
import seaborn as sns
import h5py as h5
# %matplotlib inline
#from string import ascii_letters

# %%
df =pd.read_pickle('../pickle_pd/second_pd_top_25.pkl')
features = list(df)[:-1]

# %%
qt = QuantileTransformer(random_state=0)
df[features] = qt.fit_transform(df[features])

# %%
df.head()
# Out:
#    lep_pt_2    met_et  lep_pt_1     jet_n   lep_E_1  lep_eta_0  jet_pt_0  \
# 0  0.827001  0.380512  0.876871  0.000000  0.679856   0.299734  0.000000
# 1  0.000000  0.087919  0.823059  0.000000  0.629127   0.640667  0.000000
# 2  0.889522  0.105194  0.944168  0.413914  0.816004   0.917707  0.332354
# 3  0.959527  0.135238  0.738807  0.000000  0.898591   0.496582  0.000000
# 4  0.000000  0.789771  0.000000  0.413914  0.000000   0.497493  0.906905
#
#    jet_pt_1  lep_phi_1  lep_eta_1  ...     jet_m  jet_eta_1   lep_E_0  \
# 0       0.0   0.076109   0.306802  ...  0.095420   0.502002  0.450911
# 1       0.0   0.150230   0.683559  ...  0.095420   0.502002  0.297723
# 2       0.0   0.813354   0.805162  ...  0.139560   0.502002  0.726758
# 3       0.0   0.862741   0.939720  ...  0.139560   0.502002  0.010326
# 4       0.0   0.500501   0.498498  ...  0.906466   0.502002  0.466519
#
#    lep_pt_3   jet_E_0  jet_pt_2  lep_charge_1  lep_charge_0  jet_E_1  label
# 0  0.000000  0.000000       0.0      0.000000           1.0      0.0      0
# 1  0.000000  0.000000       0.0      0.000000           1.0      0.0      0
# 2  0.957515  0.419390       0.0      0.000000           1.0      0.0      0
# 3  0.976537  0.000000       0.0      1.000000           0.0      0.0      0
# 4  0.000000  0.783745       0.0      0.504004           1.0      0.0      0
#
# [5 rows x 26 columns]

# %%
 X_train, X_test, y_train, y_test = train_test_split( df[features], df['label'], test_size=0.4, random_state=42,shuffle = True)
 X_test, X_val, y_test, y_val = train_test_split( X_test, y_test, test_size=0.5, random_state=42,shuffle = True)

# %%
space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        #'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 1,50,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.6,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': hp.choice('n_estimators', [300, 400, 500, 600]),
        'seed': 0
    }

# %%
def objective(space):
    clf=xgb.XGBClassifier(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']),
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']), reg_lambda= space['reg_lambda'])
    
    evaluation = [( X_train, y_train), ( X_test, y_test)]
    
    clf.fit(X_train, y_train,
            eval_set=evaluation, #eval_metric="auc",
            early_stopping_rounds=10,verbose=False)
    

    pred = clf.predict(X_train)
    accuracy = accuracy_score(y_train, pred)
    pred_val = clf.predict(X_test)
    val_accuracy = accuracy_score(y_test, pred_val)
    delta_accuracy = accuracy - val_accuracy
    print ("SCORE:", accuracy)
    return {'loss': -val_accuracy, 'accuracy': accuracy, 'val_accuracy': val_accuracy, 'delta_accuracy':delta_accuracy, 'status': STATUS_OK }

# %%
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 50,
                        trials = trials)
# Out:
#   0%|                                  | 0/50 [00:00<?, ?trial/s, best loss=?]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8110158343015719
#   2%|▏      | 1/50 [00:52<43:15, 52.97s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8090889595196257
#   4%|▎      | 2/50 [01:38<38:46, 48.47s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8116431888817405
#   6%|▍      | 3/50 [02:40<43:00, 54.90s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8768752620645727
#   8%|▌      | 4/50 [03:16<36:08, 47.15s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8077190219670126
#  10%|▋      | 5/50 [03:44<30:17, 40.38s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8120656929867519
#  12%|▊      | 6/50 [04:37<32:50, 44.77s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8078086440498939
#  14%|▉      | 7/50 [05:07<28:36, 39.91s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8099563732503688
#  16%|█      | 8/50 [05:54<29:22, 41.95s/trial, best loss: -0.8076165967294341]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8094378454851275
#  18%|█▍      | 9/50 [06:44<30:32, 44.69s/trial, best loss: -0.807722222755687]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8146359262922384
#  20%|█▍     | 10/50 [07:48<33:48, 50.71s/trial, best loss: -0.807722222755687]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8085352230789666
#  22%|█▌     | 11/50 [08:53<35:48, 55.08s/trial, best loss: -0.807722222755687]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8102604481744302
#  24%|█▋     | 12/50 [09:47<34:36, 54.65s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8091753808138326
#  26%|█▊     | 13/50 [11:13<39:34, 64.18s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8117904251607596
#  28%|█▉     | 14/50 [12:44<43:25, 72.37s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8480009474334476
#  30%|██     | 15/50 [13:47<40:29, 69.41s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8139637606706293
#  32%|██▏    | 16/50 [15:21<43:35, 76.93s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8172765769485602
#  34%|██▍    | 17/50 [16:35<41:43, 75.86s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8078470535139859
#  36%|██▌    | 18/50 [17:20<35:28, 66.50s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.808800888538936
#  38%|██▋    | 19/50 [18:13<32:21, 62.64s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8205797908604681
#  40%|██▊    | 20/50 [19:07<29:57, 59.91s/trial, best loss: -0.807751029853756]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8091913847572042
#  42%|██▌   | 21/50 [20:05<28:40, 59.33s/trial, best loss: -0.8079814866383077]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8092393965873191
#  44%|██▋   | 22/50 [21:02<27:23, 58.69s/trial, best loss: -0.8079814866383077]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8091369713497406
#  46%|██▊   | 23/50 [21:58<26:06, 58.02s/trial, best loss: -0.8079814866383077]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.809130569772392
#  48%|██▉   | 24/50 [22:55<25:01, 57.76s/trial, best loss: -0.8079814866383077]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.809549873088729
#  50%|█▌ | 25/50 [56:48<4:30:54, 650.20s/trial, best loss: -0.8079814866383077]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8096747038470279
#  52%|▌| 26/50 [3:38:35<22:26:59, 3367.50s/trial, best loss: -0.807981486638307
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8098635503788133
#  54%|▌| 27/50 [6:28:27<34:35:45, 5415.04s/trial, best loss: -0.807981486638307
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.810190030823595
#  56%|▌| 28/50 [9:27:48<42:53:38, 7019.00s/trial, best loss: -0.807981486638307
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8113807242104455
#  58%|▌| 29/50 [10:00:24<32:04:59, 5499.96s/trial, best loss: -0.80798148663830
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8098251409147214
#  60%|▌| 30/50 [10:01:19<21:28:46, 3866.30s/trial, best loss: -0.80801029373637
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.809335420247549
#  62%|▌| 31/50 [10:02:19<14:22:43, 2724.37s/trial, best loss: -0.80801029373637
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8143574576775717
#  64%|▋| 32/50 [10:03:08<9:36:32, 1921.79s/trial, best loss: -0.808010293736376
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8109774248374799
#  66%|▋| 33/50 [10:04:21<6:27:24, 1367.30s/trial, best loss: -0.808010293736376
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8100748024313191
#  68%|▋| 34/50 [10:05:32<4:20:55, 978.46s/trial, best loss: -0.8080102937363767
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8088617035237482
#  70%|▋| 35/50 [10:06:23<2:55:03, 700.23s/trial, best loss: -0.8080102937363767
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8096490975376333
#  72%|▋| 36/50 [10:07:07<1:57:27, 503.40s/trial, best loss: -0.8080102937363767
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8108333893471351
#  74%|▋| 37/50 [10:08:36<1:22:07, 379.07s/trial, best loss: -0.8080102937363767
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8078502543026602
#  76%|█▌| 38/50 [10:09:21<55:45, 278.76s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8109742240488056
#  78%|█▌| 39/50 [10:10:38<39:58, 218.08s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8087848845955643
#  80%|█▌| 40/50 [10:11:13<27:11, 163.15s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8090025382254188
#  82%|█▋| 41/50 [10:12:12<19:47, 131.90s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8110702477090355
#  84%|█▋| 42/50 [10:13:49<16:11, 121.47s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8086376483165452
#  86%|█▋| 43/50 [10:14:44<11:50, 101.54s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.808480809671503
#  88%|██▋| 44/50 [10:15:33<08:35, 85.99s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8094442470624762
#  90%|██▋| 45/50 [10:16:57<07:06, 85.36s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8095306683566831
#  92%|██▊| 46/50 [10:18:19<05:36, 84.17s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8096554991149819
#  94%|██▊| 47/50 [10:19:08<03:41, 73.77s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8117904251607596
#  96%|██▉| 48/50 [10:20:38<02:37, 78.60s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8158874346639012
#  98%|██▉| 49/50 [10:22:27<01:27, 87.76s/trial, best loss: -0.8080102937363767]
# /Users/ndueser/Documents/Niklas/ML_Seminar/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# SCORE:
# 0.8084648057281314
# 100%|██| 50/50 [10:23:20<00:00, 748.01s/trial, best loss: -0.8080102937363767]

# %%
best_hyperparams
# Out:
# {'colsample_bytree': 0.7835361011051029,
#  'max_depth': 4.0,
#  'min_child_weight': 7.0,
#  'n_estimators': 3,
#  'reg_alpha': 33.0,
#  'reg_lambda': 0.46159501019482946}

# %%
trial_res = pd.DataFrame()
for keys in trials.trials[0]['misc']['vals'].keys():
    trial_res[keys] = pd.Series([trial['misc']['vals'][keys] for trial in trials.trials])
trial_res = trial_res.apply(pd.Series.squeeze)
trial_res['train_accuracy'] = [trial['result']['accuracy'] for trial in trials.trials]
trial_res['val_accuracy'] = [trial['result']['val_accuracy'] for trial in trials.trials]
trial_res['delta_accuracy'] = [trial['result']['delta_accuracy'] for trial in trials.trials]
col_names = list(trial_res)
trial_res = pd.concat((pd.DataFrame(trial_res[col].tolist()) for col in list(trial_res)), axis=1)
trial_res.columns = col_names
trial_res['Selection'] = np.zeros(len(trial_res))
trial_res['Selection'][trials.best_trial['tid']] = "best"
for i, n in zip([0, 1, 2, 3], [300, 400, 500, 600]):
    trial_res['n_estimators'][trial_res['n_estimators']== i] = n
# Out:
# /var/folders/jg/_qgpsg4n22d16c3lpjt2qdk80000gn/T/ipykernel_54711/2052536915.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_res['Selection'][trials.best_trial['tid']] = "best"
# /var/folders/jg/_qgpsg4n22d16c3lpjt2qdk80000gn/T/ipykernel_54711/2052536915.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_res['n_estimators'][trial_res['n_estimators']== i] = n
# /var/folders/jg/_qgpsg4n22d16c3lpjt2qdk80000gn/T/ipykernel_54711/2052536915.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_res['n_estimators'][trial_res['n_estimators']== i] = n
# /var/folders/jg/_qgpsg4n22d16c3lpjt2qdk80000gn/T/ipykernel_54711/2052536915.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_res['n_estimators'][trial_res['n_estimators']== i] = n
# /var/folders/jg/_qgpsg4n22d16c3lpjt2qdk80000gn/T/ipykernel_54711/2052536915.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_res['n_estimators'][trial_res['n_estimators']== i] = n

# %%
trial_res.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 trial_res.head()
#
# NameError: name 'trial_res' is not defined

# %%
sns.set(font_scale = 3)
sns.pairplot(trial_res, x_vars=['n_estimators', 'colsample_bytree', 'max_depth', 'min_child_weight', 'reg_alpha', 'reg_lambda' ], y_vars=['train_accuracy','val_accuracy','delta_accuracy'], kind='reg',  height=5, hue = 'Selection')

# %%
xgb_model=xgb.XGBClassifier(
                    n_estimators =[200,300,400, 500, 600][best_hyperparams['n_estimators']], max_depth = int(best_hyperparams['max_depth']),
                    reg_alpha = int(best_hyperparams['reg_alpha']),min_child_weight=int(best_hyperparams['min_child_weight']),
                    colsample_bytree=int(best_hyperparams['colsample_bytree']), reg_lambda=best_hyperparams['reg_lambda'])         
xgb_model.fit(X_train[features],y_train,
             eval_set = [( X_train, y_train), ( X_test, y_test)])
#y_pred = xgb_model.predict(X_val[features])
# Out:
# [0]	validation_0-mlogloss:1.02633	validation_1-mlogloss:1.02644
# [1]	validation_0-mlogloss:0.95998	validation_1-mlogloss:0.96028
# [2]	validation_0-mlogloss:0.92727	validation_1-mlogloss:0.92766
# [3]	validation_0-mlogloss:0.91911	validation_1-mlogloss:0.91972
# [4]	validation_0-mlogloss:0.89778	validation_1-mlogloss:0.89850
# [5]	validation_0-mlogloss:0.88132	validation_1-mlogloss:0.88213
# [6]	validation_0-mlogloss:0.85935	validation_1-mlogloss:0.86018
# [7]	validation_0-mlogloss:0.85326	validation_1-mlogloss:0.85420
# [8]	validation_0-mlogloss:0.83564	validation_1-mlogloss:0.83667
# [9]	validation_0-mlogloss:0.80800	validation_1-mlogloss:0.80895
# [10]	validation_0-mlogloss:0.74304	validation_1-mlogloss:0.74308
# [11]	validation_0-mlogloss:0.72010	validation_1-mlogloss:0.71995
# [12]	validation_0-mlogloss:0.71398	validation_1-mlogloss:0.71370
# [13]	validation_0-mlogloss:0.69751	validation_1-mlogloss:0.69759
# [14]	validation_0-mlogloss:0.67508	validation_1-mlogloss:0.67505
# [15]	validation_0-mlogloss:0.67369	validation_1-mlogloss:0.67377
# [16]	validation_0-mlogloss:0.65859	validation_1-mlogloss:0.65879
# [17]	validation_0-mlogloss:0.64863	validation_1-mlogloss:0.64904
# [18]	validation_0-mlogloss:0.63920	validation_1-mlogloss:0.63967
# [19]	validation_0-mlogloss:0.62272	validation_1-mlogloss:0.62303
# [20]	validation_0-mlogloss:0.60927	validation_1-mlogloss:0.60964
# [21]	validation_0-mlogloss:0.60623	validation_1-mlogloss:0.60659
# [22]	validation_0-mlogloss:0.60199	validation_1-mlogloss:0.60241
# [23]	validation_0-mlogloss:0.59921	validation_1-mlogloss:0.59966
# [24]	validation_0-mlogloss:0.58427	validation_1-mlogloss:0.58453
# [25]	validation_0-mlogloss:0.57779	validation_1-mlogloss:0.57817
# [26]	validation_0-mlogloss:0.57508	validation_1-mlogloss:0.57554
# [27]	validation_0-mlogloss:0.56476	validation_1-mlogloss:0.56510
# [28]	validation_0-mlogloss:0.55471	validation_1-mlogloss:0.55500
# [29]	validation_0-mlogloss:0.55356	validation_1-mlogloss:0.55387
# [30]	validation_0-mlogloss:0.55143	validation_1-mlogloss:0.55179
# [31]	validation_0-mlogloss:0.55089	validation_1-mlogloss:0.55129
# [32]	validation_0-mlogloss:0.54824	validation_1-mlogloss:0.54868
# [33]	validation_0-mlogloss:0.54642	validation_1-mlogloss:0.54696
# [34]	validation_0-mlogloss:0.54584	validation_1-mlogloss:0.54641
# [35]	validation_0-mlogloss:0.54523	validation_1-mlogloss:0.54584
# [36]	validation_0-mlogloss:0.54432	validation_1-mlogloss:0.54493
# [37]	validation_0-mlogloss:0.54192	validation_1-mlogloss:0.54245
# [38]	validation_0-mlogloss:0.53876	validation_1-mlogloss:0.53926
# [39]	validation_0-mlogloss:0.52953	validation_1-mlogloss:0.52997
# [40]	validation_0-mlogloss:0.52865	validation_1-mlogloss:0.52919
# [41]	validation_0-mlogloss:0.52695	validation_1-mlogloss:0.52751
# [42]	validation_0-mlogloss:0.52572	validation_1-mlogloss:0.52631
# [43]	validation_0-mlogloss:0.52409	validation_1-mlogloss:0.52463
# [44]	validation_0-mlogloss:0.52269	validation_1-mlogloss:0.52326
# [45]	validation_0-mlogloss:0.51754	validation_1-mlogloss:0.51808
# [46]	validation_0-mlogloss:0.51707	validation_1-mlogloss:0.51759
# [47]	validation_0-mlogloss:0.51667	validation_1-mlogloss:0.51724
# [48]	validation_0-mlogloss:0.51624	validation_1-mlogloss:0.51686
# [49]	validation_0-mlogloss:0.51562	validation_1-mlogloss:0.51621
# [50]	validation_0-mlogloss:0.51448	validation_1-mlogloss:0.51519
# [51]	validation_0-mlogloss:0.51416	validation_1-mlogloss:0.51489
# [52]	validation_0-mlogloss:0.51383	validation_1-mlogloss:0.51458
# [53]	validation_0-mlogloss:0.51348	validation_1-mlogloss:0.51428
# [54]	validation_0-mlogloss:0.51228	validation_1-mlogloss:0.51314
# [55]	validation_0-mlogloss:0.50760	validation_1-mlogloss:0.50838
# [56]	validation_0-mlogloss:0.50662	validation_1-mlogloss:0.50757
# [57]	validation_0-mlogloss:0.50631	validation_1-mlogloss:0.50733
# [58]	validation_0-mlogloss:0.50617	validation_1-mlogloss:0.50722
# [59]	validation_0-mlogloss:0.50289	validation_1-mlogloss:0.50390
# [60]	validation_0-mlogloss:0.50215	validation_1-mlogloss:0.50318
# [61]	validation_0-mlogloss:0.50170	validation_1-mlogloss:0.50279
# [62]	validation_0-mlogloss:0.50129	validation_1-mlogloss:0.50243
# [63]	validation_0-mlogloss:0.50037	validation_1-mlogloss:0.50150
# [64]	validation_0-mlogloss:0.49593	validation_1-mlogloss:0.49701
# [65]	validation_0-mlogloss:0.49587	validation_1-mlogloss:0.49698
# [66]	validation_0-mlogloss:0.49259	validation_1-mlogloss:0.49352
# [67]	validation_0-mlogloss:0.49219	validation_1-mlogloss:0.49314
# [68]	validation_0-mlogloss:0.49178	validation_1-mlogloss:0.49271
# [69]	validation_0-mlogloss:0.49125	validation_1-mlogloss:0.49224
# [70]	validation_0-mlogloss:0.49050	validation_1-mlogloss:0.49151
# [71]	validation_0-mlogloss:0.48809	validation_1-mlogloss:0.48903
# [72]	validation_0-mlogloss:0.48788	validation_1-mlogloss:0.48886
# [73]	validation_0-mlogloss:0.48394	validation_1-mlogloss:0.48486
# [74]	validation_0-mlogloss:0.48308	validation_1-mlogloss:0.48395
# [75]	validation_0-mlogloss:0.48282	validation_1-mlogloss:0.48370
# [76]	validation_0-mlogloss:0.48276	validation_1-mlogloss:0.48364
# [77]	validation_0-mlogloss:0.48174	validation_1-mlogloss:0.48259
# [78]	validation_0-mlogloss:0.48121	validation_1-mlogloss:0.48206
# [79]	validation_0-mlogloss:0.48107	validation_1-mlogloss:0.48195
# [80]	validation_0-mlogloss:0.48099	validation_1-mlogloss:0.48191
# [81]	validation_0-mlogloss:0.48056	validation_1-mlogloss:0.48151
# [82]	validation_0-mlogloss:0.48034	validation_1-mlogloss:0.48128
# [83]	validation_0-mlogloss:0.48025	validation_1-mlogloss:0.48121
# [84]	validation_0-mlogloss:0.47920	validation_1-mlogloss:0.48009
# [85]	validation_0-mlogloss:0.47819	validation_1-mlogloss:0.47914
# [86]	validation_0-mlogloss:0.47794	validation_1-mlogloss:0.47891
# [87]	validation_0-mlogloss:0.47782	validation_1-mlogloss:0.47880
# [88]	validation_0-mlogloss:0.47680	validation_1-mlogloss:0.47779
# [89]	validation_0-mlogloss:0.47672	validation_1-mlogloss:0.47773
# [90]	validation_0-mlogloss:0.47601	validation_1-mlogloss:0.47712
# [91]	validation_0-mlogloss:0.47573	validation_1-mlogloss:0.47689
# [92]	validation_0-mlogloss:0.47467	validation_1-mlogloss:0.47580
# [93]	validation_0-mlogloss:0.47443	validation_1-mlogloss:0.47557
# [94]	validation_0-mlogloss:0.47440	validation_1-mlogloss:0.47556
# [95]	validation_0-mlogloss:0.47418	validation_1-mlogloss:0.47533
# [96]	validation_0-mlogloss:0.47331	validation_1-mlogloss:0.47438
# [97]	validation_0-mlogloss:0.47308	validation_1-mlogloss:0.47420
# [98]	validation_0-mlogloss:0.47303	validation_1-mlogloss:0.47416
# [99]	validation_0-mlogloss:0.47275	validation_1-mlogloss:0.47395
# [100]	validation_0-mlogloss:0.47261	validation_1-mlogloss:0.47380
# [101]	validation_0-mlogloss:0.47233	validation_1-mlogloss:0.47355
# [102]	validation_0-mlogloss:0.47151	validation_1-mlogloss:0.47270
# [103]	validation_0-mlogloss:0.47114	validation_1-mlogloss:0.47235
# [104]	validation_0-mlogloss:0.47088	validation_1-mlogloss:0.47213
# [105]	validation_0-mlogloss:0.47009	validation_1-mlogloss:0.47143
# [106]	validation_0-mlogloss:0.46986	validation_1-mlogloss:0.47122
# [107]	validation_0-mlogloss:0.46791	validation_1-mlogloss:0.46918
# [108]	validation_0-mlogloss:0.46743	validation_1-mlogloss:0.46872
# [109]	validation_0-mlogloss:0.46714	validation_1-mlogloss:0.46849
# [110]	validation_0-mlogloss:0.46701	validation_1-mlogloss:0.46838
# [111]	validation_0-mlogloss:0.46669	validation_1-mlogloss:0.46810
# [112]	validation_0-mlogloss:0.46663	validation_1-mlogloss:0.46804
# [113]	validation_0-mlogloss:0.46658	validation_1-mlogloss:0.46800
# [114]	validation_0-mlogloss:0.46630	validation_1-mlogloss:0.46772
# [115]	validation_0-mlogloss:0.46619	validation_1-mlogloss:0.46766
# [116]	validation_0-mlogloss:0.46609	validation_1-mlogloss:0.46755
# [117]	validation_0-mlogloss:0.46606	validation_1-mlogloss:0.46752
# [118]	validation_0-mlogloss:0.46522	validation_1-mlogloss:0.46659
# [119]	validation_0-mlogloss:0.46495	validation_1-mlogloss:0.46638
# [120]	validation_0-mlogloss:0.46460	validation_1-mlogloss:0.46606
# [121]	validation_0-mlogloss:0.46418	validation_1-mlogloss:0.46570
# [122]	validation_0-mlogloss:0.46393	validation_1-mlogloss:0.46548
# [123]	validation_0-mlogloss:0.46381	validation_1-mlogloss:0.46540
# [124]	validation_0-mlogloss:0.46257	validation_1-mlogloss:0.46413
# [125]	validation_0-mlogloss:0.46227	validation_1-mlogloss:0.46383
# [126]	validation_0-mlogloss:0.46181	validation_1-mlogloss:0.46337
# [127]	validation_0-mlogloss:0.46169	validation_1-mlogloss:0.46329
# [128]	validation_0-mlogloss:0.46162	validation_1-mlogloss:0.46322
# [129]	validation_0-mlogloss:0.46148	validation_1-mlogloss:0.46308
# [130]	validation_0-mlogloss:0.46135	validation_1-mlogloss:0.46298
# [131]	validation_0-mlogloss:0.46086	validation_1-mlogloss:0.46251
# [132]	validation_0-mlogloss:0.46069	validation_1-mlogloss:0.46236
# [133]	validation_0-mlogloss:0.46063	validation_1-mlogloss:0.46231
# [134]	validation_0-mlogloss:0.46018	validation_1-mlogloss:0.46180
# [135]	validation_0-mlogloss:0.46010	validation_1-mlogloss:0.46174
# [136]	validation_0-mlogloss:0.45925	validation_1-mlogloss:0.46088
# [137]	validation_0-mlogloss:0.45902	validation_1-mlogloss:0.46064
# [138]	validation_0-mlogloss:0.45845	validation_1-mlogloss:0.46006
# [139]	validation_0-mlogloss:0.45843	validation_1-mlogloss:0.46005
# [140]	validation_0-mlogloss:0.45822	validation_1-mlogloss:0.45988
# [141]	validation_0-mlogloss:0.45810	validation_1-mlogloss:0.45979
# [142]	validation_0-mlogloss:0.45802	validation_1-mlogloss:0.45972
# [143]	validation_0-mlogloss:0.45800	validation_1-mlogloss:0.45970
# [144]	validation_0-mlogloss:0.45797	validation_1-mlogloss:0.45968
# [145]	validation_0-mlogloss:0.45795	validation_1-mlogloss:0.45968
# [146]	validation_0-mlogloss:0.45787	validation_1-mlogloss:0.45959
# [147]	validation_0-mlogloss:0.45771	validation_1-mlogloss:0.45945
# [148]	validation_0-mlogloss:0.45742	validation_1-mlogloss:0.45913
# [149]	validation_0-mlogloss:0.45716	validation_1-mlogloss:0.45883
# [150]	validation_0-mlogloss:0.45702	validation_1-mlogloss:0.45874
# [151]	validation_0-mlogloss:0.45684	validation_1-mlogloss:0.45860
# [152]	validation_0-mlogloss:0.45682	validation_1-mlogloss:0.45860
# [153]	validation_0-mlogloss:0.45677	validation_1-mlogloss:0.45855
# [154]	validation_0-mlogloss:0.45666	validation_1-mlogloss:0.45847
# [155]	validation_0-mlogloss:0.45653	validation_1-mlogloss:0.45838
# [156]	validation_0-mlogloss:0.45638	validation_1-mlogloss:0.45824
# [157]	validation_0-mlogloss:0.45608	validation_1-mlogloss:0.45793
# [158]	validation_0-mlogloss:0.45605	validation_1-mlogloss:0.45790
# [159]	validation_0-mlogloss:0.45603	validation_1-mlogloss:0.45789
# [160]	validation_0-mlogloss:0.45590	validation_1-mlogloss:0.45779
# [161]	validation_0-mlogloss:0.45568	validation_1-mlogloss:0.45755
# [162]	validation_0-mlogloss:0.45563	validation_1-mlogloss:0.45753
# [163]	validation_0-mlogloss:0.45551	validation_1-mlogloss:0.45741
# [164]	validation_0-mlogloss:0.45533	validation_1-mlogloss:0.45722
# [165]	validation_0-mlogloss:0.45472	validation_1-mlogloss:0.45662
# [166]	validation_0-mlogloss:0.45469	validation_1-mlogloss:0.45660
# [167]	validation_0-mlogloss:0.45468	validation_1-mlogloss:0.45660
# [168]	validation_0-mlogloss:0.45459	validation_1-mlogloss:0.45653
# [169]	validation_0-mlogloss:0.45457	validation_1-mlogloss:0.45652
# [170]	validation_0-mlogloss:0.45443	validation_1-mlogloss:0.45642
# [171]	validation_0-mlogloss:0.45442	validation_1-mlogloss:0.45643
# [172]	validation_0-mlogloss:0.45426	validation_1-mlogloss:0.45628
# [173]	validation_0-mlogloss:0.45424	validation_1-mlogloss:0.45627
# [174]	validation_0-mlogloss:0.45419	validation_1-mlogloss:0.45625
# [175]	validation_0-mlogloss:0.45413	validation_1-mlogloss:0.45618
# [176]	validation_0-mlogloss:0.45404	validation_1-mlogloss:0.45613
# [177]	validation_0-mlogloss:0.45402	validation_1-mlogloss:0.45612
# [178]	validation_0-mlogloss:0.45388	validation_1-mlogloss:0.45596
# [179]	validation_0-mlogloss:0.45376	validation_1-mlogloss:0.45585
# [180]	validation_0-mlogloss:0.45371	validation_1-mlogloss:0.45582
# [181]	validation_0-mlogloss:0.45351	validation_1-mlogloss:0.45564
# [182]	validation_0-mlogloss:0.45337	validation_1-mlogloss:0.45548
# [183]	validation_0-mlogloss:0.45333	validation_1-mlogloss:0.45546
# [184]	validation_0-mlogloss:0.45317	validation_1-mlogloss:0.45532
# [185]	validation_0-mlogloss:0.45316	validation_1-mlogloss:0.45532
# [186]	validation_0-mlogloss:0.45313	validation_1-mlogloss:0.45530
# [187]	validation_0-mlogloss:0.45296	validation_1-mlogloss:0.45515
# [188]	validation_0-mlogloss:0.45286	validation_1-mlogloss:0.45507
# [189]	validation_0-mlogloss:0.45282	validation_1-mlogloss:0.45502
# [190]	validation_0-mlogloss:0.45273	validation_1-mlogloss:0.45495
# [191]	validation_0-mlogloss:0.45264	validation_1-mlogloss:0.45487
# [192]	validation_0-mlogloss:0.45259	validation_1-mlogloss:0.45483
# [193]	validation_0-mlogloss:0.45254	validation_1-mlogloss:0.45480
# [194]	validation_0-mlogloss:0.45251	validation_1-mlogloss:0.45478
# [195]	validation_0-mlogloss:0.45247	validation_1-mlogloss:0.45473
# [196]	validation_0-mlogloss:0.45246	validation_1-mlogloss:0.45471
# [197]	validation_0-mlogloss:0.45232	validation_1-mlogloss:0.45461
# [198]	validation_0-mlogloss:0.45231	validation_1-mlogloss:0.45460
# [199]	validation_0-mlogloss:0.45227	validation_1-mlogloss:0.45457
# [200]	validation_0-mlogloss:0.45224	validation_1-mlogloss:0.45453
# [201]	validation_0-mlogloss:0.45219	validation_1-mlogloss:0.45447
# [202]	validation_0-mlogloss:0.45216	validation_1-mlogloss:0.45446
# [203]	validation_0-mlogloss:0.45212	validation_1-mlogloss:0.45443
# [204]	validation_0-mlogloss:0.45211	validation_1-mlogloss:0.45443
# [205]	validation_0-mlogloss:0.45209	validation_1-mlogloss:0.45441
# [206]	validation_0-mlogloss:0.45207	validation_1-mlogloss:0.45440
# [207]	validation_0-mlogloss:0.45201	validation_1-mlogloss:0.45437
# [208]	validation_0-mlogloss:0.45186	validation_1-mlogloss:0.45420
# [209]	validation_0-mlogloss:0.45184	validation_1-mlogloss:0.45420
# [210]	validation_0-mlogloss:0.45180	validation_1-mlogloss:0.45419
# [211]	validation_0-mlogloss:0.45174	validation_1-mlogloss:0.45412
# [212]	validation_0-mlogloss:0.45160	validation_1-mlogloss:0.45397
# [213]	validation_0-mlogloss:0.45157	validation_1-mlogloss:0.45393
# [214]	validation_0-mlogloss:0.45149	validation_1-mlogloss:0.45386
# [215]	validation_0-mlogloss:0.45147	validation_1-mlogloss:0.45385
# [216]	validation_0-mlogloss:0.45145	validation_1-mlogloss:0.45384
# [217]	validation_0-mlogloss:0.45139	validation_1-mlogloss:0.45381
# [218]	validation_0-mlogloss:0.45136	validation_1-mlogloss:0.45379
# [219]	validation_0-mlogloss:0.45130	validation_1-mlogloss:0.45375
# [220]	validation_0-mlogloss:0.45116	validation_1-mlogloss:0.45366
# [221]	validation_0-mlogloss:0.45114	validation_1-mlogloss:0.45364
# [222]	validation_0-mlogloss:0.45112	validation_1-mlogloss:0.45362
# [223]	validation_0-mlogloss:0.45110	validation_1-mlogloss:0.45361
# [224]	validation_0-mlogloss:0.45109	validation_1-mlogloss:0.45361
# [225]	validation_0-mlogloss:0.45106	validation_1-mlogloss:0.45359
# [226]	validation_0-mlogloss:0.45104	validation_1-mlogloss:0.45357
# [227]	validation_0-mlogloss:0.45100	validation_1-mlogloss:0.45355
# [228]	validation_0-mlogloss:0.45098	validation_1-mlogloss:0.45354
# [229]	validation_0-mlogloss:0.45094	validation_1-mlogloss:0.45351
# [230]	validation_0-mlogloss:0.45088	validation_1-mlogloss:0.45346
# [231]	validation_0-mlogloss:0.45080	validation_1-mlogloss:0.45339
# [232]	validation_0-mlogloss:0.45076	validation_1-mlogloss:0.45334
# [233]	validation_0-mlogloss:0.45059	validation_1-mlogloss:0.45317
# [234]	validation_0-mlogloss:0.45059	validation_1-mlogloss:0.45317
# [235]	validation_0-mlogloss:0.45053	validation_1-mlogloss:0.45314
# [236]	validation_0-mlogloss:0.45051	validation_1-mlogloss:0.45312
# [237]	validation_0-mlogloss:0.45049	validation_1-mlogloss:0.45312
# [238]	validation_0-mlogloss:0.45041	validation_1-mlogloss:0.45302
# [239]	validation_0-mlogloss:0.45036	validation_1-mlogloss:0.45298
# [240]	validation_0-mlogloss:0.45026	validation_1-mlogloss:0.45287
# [241]	validation_0-mlogloss:0.45024	validation_1-mlogloss:0.45286
# [242]	validation_0-mlogloss:0.45023	validation_1-mlogloss:0.45285
# [243]	validation_0-mlogloss:0.45015	validation_1-mlogloss:0.45279
# [244]	validation_0-mlogloss:0.45010	validation_1-mlogloss:0.45277
# [245]	validation_0-mlogloss:0.45009	validation_1-mlogloss:0.45277
# [246]	validation_0-mlogloss:0.45008	validation_1-mlogloss:0.45277
# [247]	validation_0-mlogloss:0.45005	validation_1-mlogloss:0.45276
# [248]	validation_0-mlogloss:0.45000	validation_1-mlogloss:0.45272
# [249]	validation_0-mlogloss:0.44995	validation_1-mlogloss:0.45267
# [250]	validation_0-mlogloss:0.44989	validation_1-mlogloss:0.45263
# [251]	validation_0-mlogloss:0.44982	validation_1-mlogloss:0.45258
# [252]	validation_0-mlogloss:0.44981	validation_1-mlogloss:0.45257
# [253]	validation_0-mlogloss:0.44974	validation_1-mlogloss:0.45249
# [254]	validation_0-mlogloss:0.44972	validation_1-mlogloss:0.45248
# [255]	validation_0-mlogloss:0.44969	validation_1-mlogloss:0.45247
# [256]	validation_0-mlogloss:0.44966	validation_1-mlogloss:0.45244
# [257]	validation_0-mlogloss:0.44962	validation_1-mlogloss:0.45243
# [258]	validation_0-mlogloss:0.44961	validation_1-mlogloss:0.45243
# [259]	validation_0-mlogloss:0.44959	validation_1-mlogloss:0.45242
# [260]	validation_0-mlogloss:0.44955	validation_1-mlogloss:0.45239
# [261]	validation_0-mlogloss:0.44949	validation_1-mlogloss:0.45234
# [262]	validation_0-mlogloss:0.44918	validation_1-mlogloss:0.45202
# [263]	validation_0-mlogloss:0.44915	validation_1-mlogloss:0.45200
# [264]	validation_0-mlogloss:0.44907	validation_1-mlogloss:0.45192
# [265]	validation_0-mlogloss:0.44899	validation_1-mlogloss:0.45182
# [266]	validation_0-mlogloss:0.44891	validation_1-mlogloss:0.45174
# [267]	validation_0-mlogloss:0.44885	validation_1-mlogloss:0.45170
# [268]	validation_0-mlogloss:0.44883	validation_1-mlogloss:0.45168
# [269]	validation_0-mlogloss:0.44881	validation_1-mlogloss:0.45167
# [270]	validation_0-mlogloss:0.44857	validation_1-mlogloss:0.45143
# [271]	validation_0-mlogloss:0.44855	validation_1-mlogloss:0.45142
# [272]	validation_0-mlogloss:0.44853	validation_1-mlogloss:0.45142
# [273]	validation_0-mlogloss:0.44851	validation_1-mlogloss:0.45141
# [274]	validation_0-mlogloss:0.44850	validation_1-mlogloss:0.45140
# [275]	validation_0-mlogloss:0.44846	validation_1-mlogloss:0.45137
# [276]	validation_0-mlogloss:0.44843	validation_1-mlogloss:0.45135
# [277]	validation_0-mlogloss:0.44841	validation_1-mlogloss:0.45134
# [278]	validation_0-mlogloss:0.44839	validation_1-mlogloss:0.45133
# [279]	validation_0-mlogloss:0.44836	validation_1-mlogloss:0.45132
# [280]	validation_0-mlogloss:0.44833	validation_1-mlogloss:0.45129
# [281]	validation_0-mlogloss:0.44833	validation_1-mlogloss:0.45129
# [282]	validation_0-mlogloss:0.44831	validation_1-mlogloss:0.45128
# [283]	validation_0-mlogloss:0.44830	validation_1-mlogloss:0.45127
# [284]	validation_0-mlogloss:0.44828	validation_1-mlogloss:0.45125
# [285]	validation_0-mlogloss:0.44826	validation_1-mlogloss:0.45124
# [286]	validation_0-mlogloss:0.44824	validation_1-mlogloss:0.45121
# [287]	validation_0-mlogloss:0.44819	validation_1-mlogloss:0.45115
# [288]	validation_0-mlogloss:0.44817	validation_1-mlogloss:0.45115
# [289]	validation_0-mlogloss:0.44813	validation_1-mlogloss:0.45111
# [290]	validation_0-mlogloss:0.44808	validation_1-mlogloss:0.45107
# [291]	validation_0-mlogloss:0.44807	validation_1-mlogloss:0.45106
# [292]	validation_0-mlogloss:0.44805	validation_1-mlogloss:0.45104
# [293]	validation_0-mlogloss:0.44803	validation_1-mlogloss:0.45102
# [294]	validation_0-mlogloss:0.44799	validation_1-mlogloss:0.45100
# [295]	validation_0-mlogloss:0.44796	validation_1-mlogloss:0.45097
# [296]	validation_0-mlogloss:0.44795	validation_1-mlogloss:0.45096
# [297]	validation_0-mlogloss:0.44794	validation_1-mlogloss:0.45096
# [298]	validation_0-mlogloss:0.44791	validation_1-mlogloss:0.45093
# [299]	validation_0-mlogloss:0.44789	validation_1-mlogloss:0.45093
# [300]	validation_0-mlogloss:0.44788	validation_1-mlogloss:0.45093
# [301]	validation_0-mlogloss:0.44785	validation_1-mlogloss:0.45092
# [302]	validation_0-mlogloss:0.44784	validation_1-mlogloss:0.45091
# [303]	validation_0-mlogloss:0.44782	validation_1-mlogloss:0.45090
# [304]	validation_0-mlogloss:0.44780	validation_1-mlogloss:0.45089
# [305]	validation_0-mlogloss:0.44777	validation_1-mlogloss:0.45085
# [306]	validation_0-mlogloss:0.44775	validation_1-mlogloss:0.45085
# [307]	validation_0-mlogloss:0.44773	validation_1-mlogloss:0.45084
# [308]	validation_0-mlogloss:0.44768	validation_1-mlogloss:0.45080
# [309]	validation_0-mlogloss:0.44764	validation_1-mlogloss:0.45078
# [310]	validation_0-mlogloss:0.44764	validation_1-mlogloss:0.45078
# [311]	validation_0-mlogloss:0.44761	validation_1-mlogloss:0.45075
# [312]	validation_0-mlogloss:0.44759	validation_1-mlogloss:0.45073
# [313]	validation_0-mlogloss:0.44757	validation_1-mlogloss:0.45071
# [314]	validation_0-mlogloss:0.44756	validation_1-mlogloss:0.45071
# [315]	validation_0-mlogloss:0.44753	validation_1-mlogloss:0.45069
# [316]	validation_0-mlogloss:0.44752	validation_1-mlogloss:0.45070
# [317]	validation_0-mlogloss:0.44751	validation_1-mlogloss:0.45070
# [318]	validation_0-mlogloss:0.44747	validation_1-mlogloss:0.45066
# [319]	validation_0-mlogloss:0.44743	validation_1-mlogloss:0.45064
# [320]	validation_0-mlogloss:0.44741	validation_1-mlogloss:0.45063
# [321]	validation_0-mlogloss:0.44740	validation_1-mlogloss:0.45063
# [322]	validation_0-mlogloss:0.44734	validation_1-mlogloss:0.45058
# [323]	validation_0-mlogloss:0.44733	validation_1-mlogloss:0.45058
# [324]	validation_0-mlogloss:0.44730	validation_1-mlogloss:0.45057
# [325]	validation_0-mlogloss:0.44728	validation_1-mlogloss:0.45054
# [326]	validation_0-mlogloss:0.44724	validation_1-mlogloss:0.45053
# [327]	validation_0-mlogloss:0.44721	validation_1-mlogloss:0.45051
# [328]	validation_0-mlogloss:0.44719	validation_1-mlogloss:0.45050
# [329]	validation_0-mlogloss:0.44719	validation_1-mlogloss:0.45050
# [330]	validation_0-mlogloss:0.44717	validation_1-mlogloss:0.45050
# [331]	validation_0-mlogloss:0.44713	validation_1-mlogloss:0.45046
# [332]	validation_0-mlogloss:0.44710	validation_1-mlogloss:0.45044
# [333]	validation_0-mlogloss:0.44709	validation_1-mlogloss:0.45043
# [334]	validation_0-mlogloss:0.44707	validation_1-mlogloss:0.45043
# [335]	validation_0-mlogloss:0.44705	validation_1-mlogloss:0.45042
# [336]	validation_0-mlogloss:0.44704	validation_1-mlogloss:0.45041
# [337]	validation_0-mlogloss:0.44703	validation_1-mlogloss:0.45040
# [338]	validation_0-mlogloss:0.44703	validation_1-mlogloss:0.45040
# [339]	validation_0-mlogloss:0.44700	validation_1-mlogloss:0.45039
# [340]	validation_0-mlogloss:0.44699	validation_1-mlogloss:0.45039
# [341]	validation_0-mlogloss:0.44698	validation_1-mlogloss:0.45038
# [342]	validation_0-mlogloss:0.44696	validation_1-mlogloss:0.45037
# [343]	validation_0-mlogloss:0.44695	validation_1-mlogloss:0.45037
# [344]	validation_0-mlogloss:0.44694	validation_1-mlogloss:0.45036
# [345]	validation_0-mlogloss:0.44689	validation_1-mlogloss:0.45033
# [346]	validation_0-mlogloss:0.44688	validation_1-mlogloss:0.45032
# [347]	validation_0-mlogloss:0.44687	validation_1-mlogloss:0.45031
# [348]	validation_0-mlogloss:0.44687	validation_1-mlogloss:0.45031
# [349]	validation_0-mlogloss:0.44687	validation_1-mlogloss:0.45031
# [350]	validation_0-mlogloss:0.44686	validation_1-mlogloss:0.45031
# [351]	validation_0-mlogloss:0.44685	validation_1-mlogloss:0.45031
# [352]	validation_0-mlogloss:0.44684	validation_1-mlogloss:0.45030
# [353]	validation_0-mlogloss:0.44682	validation_1-mlogloss:0.45029
# [354]	validation_0-mlogloss:0.44681	validation_1-mlogloss:0.45029
# [355]	validation_0-mlogloss:0.44680	validation_1-mlogloss:0.45029
# [356]	validation_0-mlogloss:0.44674	validation_1-mlogloss:0.45022
# [357]	validation_0-mlogloss:0.44669	validation_1-mlogloss:0.45015
# [358]	validation_0-mlogloss:0.44667	validation_1-mlogloss:0.45015
# [359]	validation_0-mlogloss:0.44666	validation_1-mlogloss:0.45014
# [360]	validation_0-mlogloss:0.44665	validation_1-mlogloss:0.45014
# [361]	validation_0-mlogloss:0.44663	validation_1-mlogloss:0.45015
# [362]	validation_0-mlogloss:0.44658	validation_1-mlogloss:0.45010
# [363]	validation_0-mlogloss:0.44657	validation_1-mlogloss:0.45009
# [364]	validation_0-mlogloss:0.44656	validation_1-mlogloss:0.45009
# [365]	validation_0-mlogloss:0.44653	validation_1-mlogloss:0.45005
# [366]	validation_0-mlogloss:0.44651	validation_1-mlogloss:0.45004
# [367]	validation_0-mlogloss:0.44647	validation_1-mlogloss:0.45000
# [368]	validation_0-mlogloss:0.44646	validation_1-mlogloss:0.45000
# [369]	validation_0-mlogloss:0.44643	validation_1-mlogloss:0.44999
# [370]	validation_0-mlogloss:0.44642	validation_1-mlogloss:0.44999
# [371]	validation_0-mlogloss:0.44640	validation_1-mlogloss:0.44998
# [372]	validation_0-mlogloss:0.44640	validation_1-mlogloss:0.44998
# [373]	validation_0-mlogloss:0.44639	validation_1-mlogloss:0.44998
# [374]	validation_0-mlogloss:0.44636	validation_1-mlogloss:0.44996
# [375]	validation_0-mlogloss:0.44635	validation_1-mlogloss:0.44995
# [376]	validation_0-mlogloss:0.44632	validation_1-mlogloss:0.44994
# [377]	validation_0-mlogloss:0.44631	validation_1-mlogloss:0.44994
# [378]	validation_0-mlogloss:0.44631	validation_1-mlogloss:0.44994
# [379]	validation_0-mlogloss:0.44629	validation_1-mlogloss:0.44994
# [380]	validation_0-mlogloss:0.44628	validation_1-mlogloss:0.44994
# [381]	validation_0-mlogloss:0.44627	validation_1-mlogloss:0.44994
# [382]	validation_0-mlogloss:0.44624	validation_1-mlogloss:0.44992
# [383]	validation_0-mlogloss:0.44622	validation_1-mlogloss:0.44991
# [384]	validation_0-mlogloss:0.44622	validation_1-mlogloss:0.44991
# [385]	validation_0-mlogloss:0.44621	validation_1-mlogloss:0.44990
# [386]	validation_0-mlogloss:0.44620	validation_1-mlogloss:0.44990
# [387]	validation_0-mlogloss:0.44619	validation_1-mlogloss:0.44990
# [388]	validation_0-mlogloss:0.44618	validation_1-mlogloss:0.44990
# [389]	validation_0-mlogloss:0.44616	validation_1-mlogloss:0.44990
# [390]	validation_0-mlogloss:0.44614	validation_1-mlogloss:0.44988
# [391]	validation_0-mlogloss:0.44612	validation_1-mlogloss:0.44986
# [392]	validation_0-mlogloss:0.44611	validation_1-mlogloss:0.44986
# [393]	validation_0-mlogloss:0.44610	validation_1-mlogloss:0.44985
# [394]	validation_0-mlogloss:0.44608	validation_1-mlogloss:0.44985
# [395]	validation_0-mlogloss:0.44608	validation_1-mlogloss:0.44985
# [396]	validation_0-mlogloss:0.44606	validation_1-mlogloss:0.44985
# [397]	validation_0-mlogloss:0.44605	validation_1-mlogloss:0.44985
# [398]	validation_0-mlogloss:0.44603	validation_1-mlogloss:0.44981
# [399]	validation_0-mlogloss:0.44601	validation_1-mlogloss:0.44980
# [400]	validation_0-mlogloss:0.44600	validation_1-mlogloss:0.44980
# [401]	validation_0-mlogloss:0.44599	validation_1-mlogloss:0.44979
# [402]	validation_0-mlogloss:0.44597	validation_1-mlogloss:0.44977
# [403]	validation_0-mlogloss:0.44595	validation_1-mlogloss:0.44976
# [404]	validation_0-mlogloss:0.44594	validation_1-mlogloss:0.44975
# [405]	validation_0-mlogloss:0.44592	validation_1-mlogloss:0.44975
# [406]	validation_0-mlogloss:0.44591	validation_1-mlogloss:0.44974
# [407]	validation_0-mlogloss:0.44590	validation_1-mlogloss:0.44974
# [408]	validation_0-mlogloss:0.44588	validation_1-mlogloss:0.44973
# [409]	validation_0-mlogloss:0.44587	validation_1-mlogloss:0.44973
# [410]	validation_0-mlogloss:0.44571	validation_1-mlogloss:0.44957
# [411]	validation_0-mlogloss:0.44571	validation_1-mlogloss:0.44957
# [412]	validation_0-mlogloss:0.44570	validation_1-mlogloss:0.44957
# [413]	validation_0-mlogloss:0.44569	validation_1-mlogloss:0.44956
# [414]	validation_0-mlogloss:0.44567	validation_1-mlogloss:0.44955
# [415]	validation_0-mlogloss:0.44566	validation_1-mlogloss:0.44954
# [416]	validation_0-mlogloss:0.44566	validation_1-mlogloss:0.44954
# [417]	validation_0-mlogloss:0.44565	validation_1-mlogloss:0.44954
# [418]	validation_0-mlogloss:0.44562	validation_1-mlogloss:0.44953
# [419]	validation_0-mlogloss:0.44550	validation_1-mlogloss:0.44941
# [420]	validation_0-mlogloss:0.44549	validation_1-mlogloss:0.44940
# [421]	validation_0-mlogloss:0.44548	validation_1-mlogloss:0.44939
# [422]	validation_0-mlogloss:0.44546	validation_1-mlogloss:0.44938
# [423]	validation_0-mlogloss:0.44545	validation_1-mlogloss:0.44938
# [424]	validation_0-mlogloss:0.44545	validation_1-mlogloss:0.44938
# [425]	validation_0-mlogloss:0.44544	validation_1-mlogloss:0.44938
# [426]	validation_0-mlogloss:0.44543	validation_1-mlogloss:0.44937
# [427]	validation_0-mlogloss:0.44543	validation_1-mlogloss:0.44937
# [428]	validation_0-mlogloss:0.44542	validation_1-mlogloss:0.44938
# [429]	validation_0-mlogloss:0.44541	validation_1-mlogloss:0.44938
# [430]	validation_0-mlogloss:0.44540	validation_1-mlogloss:0.44937
# [431]	validation_0-mlogloss:0.44539	validation_1-mlogloss:0.44937
# [432]	validation_0-mlogloss:0.44536	validation_1-mlogloss:0.44934
# [433]	validation_0-mlogloss:0.44535	validation_1-mlogloss:0.44934
# [434]	validation_0-mlogloss:0.44535	validation_1-mlogloss:0.44934
# [435]	validation_0-mlogloss:0.44530	validation_1-mlogloss:0.44929
# [436]	validation_0-mlogloss:0.44528	validation_1-mlogloss:0.44926
# [437]	validation_0-mlogloss:0.44527	validation_1-mlogloss:0.44925
# [438]	validation_0-mlogloss:0.44526	validation_1-mlogloss:0.44924
# [439]	validation_0-mlogloss:0.44525	validation_1-mlogloss:0.44924
# [440]	validation_0-mlogloss:0.44524	validation_1-mlogloss:0.44924
# [441]	validation_0-mlogloss:0.44522	validation_1-mlogloss:0.44923
# [442]	validation_0-mlogloss:0.44511	validation_1-mlogloss:0.44913
# [443]	validation_0-mlogloss:0.44511	validation_1-mlogloss:0.44913
# [444]	validation_0-mlogloss:0.44508	validation_1-mlogloss:0.44912
# [445]	validation_0-mlogloss:0.44507	validation_1-mlogloss:0.44912
# [446]	validation_0-mlogloss:0.44506	validation_1-mlogloss:0.44911
# [447]	validation_0-mlogloss:0.44505	validation_1-mlogloss:0.44911
# [448]	validation_0-mlogloss:0.44502	validation_1-mlogloss:0.44907
# [449]	validation_0-mlogloss:0.44502	validation_1-mlogloss:0.44906
# [450]	validation_0-mlogloss:0.44501	validation_1-mlogloss:0.44906
# [451]	validation_0-mlogloss:0.44500	validation_1-mlogloss:0.44906
# [452]	validation_0-mlogloss:0.44499	validation_1-mlogloss:0.44906
# [453]	validation_0-mlogloss:0.44491	validation_1-mlogloss:0.44898
# [454]	validation_0-mlogloss:0.44491	validation_1-mlogloss:0.44897
# [455]	validation_0-mlogloss:0.44490	validation_1-mlogloss:0.44897
# [456]	validation_0-mlogloss:0.44489	validation_1-mlogloss:0.44897
# [457]	validation_0-mlogloss:0.44487	validation_1-mlogloss:0.44894
# [458]	validation_0-mlogloss:0.44486	validation_1-mlogloss:0.44894
# [459]	validation_0-mlogloss:0.44485	validation_1-mlogloss:0.44893
# [460]	validation_0-mlogloss:0.44484	validation_1-mlogloss:0.44893
# [461]	validation_0-mlogloss:0.44483	validation_1-mlogloss:0.44893
# [462]	validation_0-mlogloss:0.44483	validation_1-mlogloss:0.44892
# [463]	validation_0-mlogloss:0.44481	validation_1-mlogloss:0.44892
# [464]	validation_0-mlogloss:0.44480	validation_1-mlogloss:0.44892
# [465]	validation_0-mlogloss:0.44480	validation_1-mlogloss:0.44891
# [466]	validation_0-mlogloss:0.44479	validation_1-mlogloss:0.44891
# [467]	validation_0-mlogloss:0.44477	validation_1-mlogloss:0.44890
# [468]	validation_0-mlogloss:0.44476	validation_1-mlogloss:0.44890
# [469]	validation_0-mlogloss:0.44476	validation_1-mlogloss:0.44890
# [470]	validation_0-mlogloss:0.44475	validation_1-mlogloss:0.44890
# [471]	validation_0-mlogloss:0.44474	validation_1-mlogloss:0.44890
# [472]	validation_0-mlogloss:0.44473	validation_1-mlogloss:0.44889
# [473]	validation_0-mlogloss:0.44473	validation_1-mlogloss:0.44889
# [474]	validation_0-mlogloss:0.44472	validation_1-mlogloss:0.44889
# [475]	validation_0-mlogloss:0.44471	validation_1-mlogloss:0.44889
# [476]	validation_0-mlogloss:0.44464	validation_1-mlogloss:0.44882
# [477]	validation_0-mlogloss:0.44463	validation_1-mlogloss:0.44882
# [478]	validation_0-mlogloss:0.44463	validation_1-mlogloss:0.44882
# [479]	validation_0-mlogloss:0.44461	validation_1-mlogloss:0.44881
# [480]	validation_0-mlogloss:0.44460	validation_1-mlogloss:0.44881
# [481]	validation_0-mlogloss:0.44458	validation_1-mlogloss:0.44880
# [482]	validation_0-mlogloss:0.44458	validation_1-mlogloss:0.44879
# [483]	validation_0-mlogloss:0.44457	validation_1-mlogloss:0.44878
# [484]	validation_0-mlogloss:0.44456	validation_1-mlogloss:0.44878
# [485]	validation_0-mlogloss:0.44455	validation_1-mlogloss:0.44878
# [486]	validation_0-mlogloss:0.44455	validation_1-mlogloss:0.44878
# [487]	validation_0-mlogloss:0.44455	validation_1-mlogloss:0.44878
# [488]	validation_0-mlogloss:0.44453	validation_1-mlogloss:0.44878
# [489]	validation_0-mlogloss:0.44452	validation_1-mlogloss:0.44877
# [490]	validation_0-mlogloss:0.44451	validation_1-mlogloss:0.44877
# [491]	validation_0-mlogloss:0.44449	validation_1-mlogloss:0.44875
# [492]	validation_0-mlogloss:0.44449	validation_1-mlogloss:0.44875
# [493]	validation_0-mlogloss:0.44447	validation_1-mlogloss:0.44874
# [494]	validation_0-mlogloss:0.44446	validation_1-mlogloss:0.44873
# [495]	validation_0-mlogloss:0.44445	validation_1-mlogloss:0.44873
# [496]	validation_0-mlogloss:0.44444	validation_1-mlogloss:0.44873
# [497]	validation_0-mlogloss:0.44444	validation_1-mlogloss:0.44873
# [498]	validation_0-mlogloss:0.44443	validation_1-mlogloss:0.44872
# [499]	validation_0-mlogloss:0.44442	validation_1-mlogloss:0.44871
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None, colsample_bytree=0,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               n_estimators=500, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
xgb_model2=xgb.XGBClassifier(
                    n_estimators =200, max_depth = int(best_hyperparams['max_depth']),
                    reg_alpha = int(best_hyperparams['reg_alpha']),min_child_weight=int(best_hyperparams['min_child_weight']),
                    colsample_bytree=int(best_hyperparams['colsample_bytree']), reg_lambda= best_hyperparams['reg_lambda'])         
xgb_model2.fit(X_train[features],y_train,
             eval_set = [( X_train, y_train), ( X_test, y_test)])
# Out:
# [0]	validation_0-mlogloss:1.02633	validation_1-mlogloss:1.02644
# [1]	validation_0-mlogloss:0.95998	validation_1-mlogloss:0.96028
# [2]	validation_0-mlogloss:0.92727	validation_1-mlogloss:0.92766
# [3]	validation_0-mlogloss:0.91911	validation_1-mlogloss:0.91972
# [4]	validation_0-mlogloss:0.89778	validation_1-mlogloss:0.89850
# [5]	validation_0-mlogloss:0.88132	validation_1-mlogloss:0.88213
# [6]	validation_0-mlogloss:0.85935	validation_1-mlogloss:0.86018
# [7]	validation_0-mlogloss:0.85326	validation_1-mlogloss:0.85420
# [8]	validation_0-mlogloss:0.83564	validation_1-mlogloss:0.83667
# [9]	validation_0-mlogloss:0.80800	validation_1-mlogloss:0.80895
# [10]	validation_0-mlogloss:0.74304	validation_1-mlogloss:0.74308
# [11]	validation_0-mlogloss:0.72010	validation_1-mlogloss:0.71995
# [12]	validation_0-mlogloss:0.71398	validation_1-mlogloss:0.71370
# [13]	validation_0-mlogloss:0.69751	validation_1-mlogloss:0.69759
# [14]	validation_0-mlogloss:0.67508	validation_1-mlogloss:0.67505
# [15]	validation_0-mlogloss:0.67369	validation_1-mlogloss:0.67377
# [16]	validation_0-mlogloss:0.65859	validation_1-mlogloss:0.65879
# [17]	validation_0-mlogloss:0.64863	validation_1-mlogloss:0.64904
# [18]	validation_0-mlogloss:0.63920	validation_1-mlogloss:0.63967
# [19]	validation_0-mlogloss:0.62272	validation_1-mlogloss:0.62303
# [20]	validation_0-mlogloss:0.60927	validation_1-mlogloss:0.60964
# [21]	validation_0-mlogloss:0.60623	validation_1-mlogloss:0.60659
# [22]	validation_0-mlogloss:0.60199	validation_1-mlogloss:0.60241
# [23]	validation_0-mlogloss:0.59921	validation_1-mlogloss:0.59966
# [24]	validation_0-mlogloss:0.58427	validation_1-mlogloss:0.58453
# [25]	validation_0-mlogloss:0.57779	validation_1-mlogloss:0.57817
# [26]	validation_0-mlogloss:0.57508	validation_1-mlogloss:0.57554
# [27]	validation_0-mlogloss:0.56476	validation_1-mlogloss:0.56510
# [28]	validation_0-mlogloss:0.55471	validation_1-mlogloss:0.55500
# [29]	validation_0-mlogloss:0.55356	validation_1-mlogloss:0.55387
# [30]	validation_0-mlogloss:0.55143	validation_1-mlogloss:0.55179
# [31]	validation_0-mlogloss:0.55089	validation_1-mlogloss:0.55129
# [32]	validation_0-mlogloss:0.54824	validation_1-mlogloss:0.54868
# [33]	validation_0-mlogloss:0.54642	validation_1-mlogloss:0.54696
# [34]	validation_0-mlogloss:0.54584	validation_1-mlogloss:0.54641
# [35]	validation_0-mlogloss:0.54523	validation_1-mlogloss:0.54584
# [36]	validation_0-mlogloss:0.54432	validation_1-mlogloss:0.54493
# [37]	validation_0-mlogloss:0.54192	validation_1-mlogloss:0.54245
# [38]	validation_0-mlogloss:0.53876	validation_1-mlogloss:0.53926
# [39]	validation_0-mlogloss:0.52953	validation_1-mlogloss:0.52997
# [40]	validation_0-mlogloss:0.52865	validation_1-mlogloss:0.52919
# [41]	validation_0-mlogloss:0.52695	validation_1-mlogloss:0.52751
# [42]	validation_0-mlogloss:0.52572	validation_1-mlogloss:0.52631
# [43]	validation_0-mlogloss:0.52409	validation_1-mlogloss:0.52463
# [44]	validation_0-mlogloss:0.52269	validation_1-mlogloss:0.52326
# [45]	validation_0-mlogloss:0.51754	validation_1-mlogloss:0.51808
# [46]	validation_0-mlogloss:0.51707	validation_1-mlogloss:0.51759
# [47]	validation_0-mlogloss:0.51667	validation_1-mlogloss:0.51724
# [48]	validation_0-mlogloss:0.51624	validation_1-mlogloss:0.51686
# [49]	validation_0-mlogloss:0.51562	validation_1-mlogloss:0.51621
# [50]	validation_0-mlogloss:0.51448	validation_1-mlogloss:0.51519
# [51]	validation_0-mlogloss:0.51416	validation_1-mlogloss:0.51489
# [52]	validation_0-mlogloss:0.51383	validation_1-mlogloss:0.51458
# [53]	validation_0-mlogloss:0.51348	validation_1-mlogloss:0.51428
# [54]	validation_0-mlogloss:0.51228	validation_1-mlogloss:0.51314
# [55]	validation_0-mlogloss:0.50760	validation_1-mlogloss:0.50838
# [56]	validation_0-mlogloss:0.50662	validation_1-mlogloss:0.50757
# [57]	validation_0-mlogloss:0.50631	validation_1-mlogloss:0.50733
# [58]	validation_0-mlogloss:0.50617	validation_1-mlogloss:0.50722
# [59]	validation_0-mlogloss:0.50289	validation_1-mlogloss:0.50390
# [60]	validation_0-mlogloss:0.50215	validation_1-mlogloss:0.50318
# [61]	validation_0-mlogloss:0.50170	validation_1-mlogloss:0.50279
# [62]	validation_0-mlogloss:0.50129	validation_1-mlogloss:0.50243
# [63]	validation_0-mlogloss:0.50037	validation_1-mlogloss:0.50150
# [64]	validation_0-mlogloss:0.49593	validation_1-mlogloss:0.49701
# [65]	validation_0-mlogloss:0.49587	validation_1-mlogloss:0.49698
# [66]	validation_0-mlogloss:0.49259	validation_1-mlogloss:0.49352
# [67]	validation_0-mlogloss:0.49219	validation_1-mlogloss:0.49314
# [68]	validation_0-mlogloss:0.49178	validation_1-mlogloss:0.49271
# [69]	validation_0-mlogloss:0.49125	validation_1-mlogloss:0.49224
# [70]	validation_0-mlogloss:0.49050	validation_1-mlogloss:0.49151
# [71]	validation_0-mlogloss:0.48809	validation_1-mlogloss:0.48903
# [72]	validation_0-mlogloss:0.48788	validation_1-mlogloss:0.48886
# [73]	validation_0-mlogloss:0.48394	validation_1-mlogloss:0.48486
# [74]	validation_0-mlogloss:0.48308	validation_1-mlogloss:0.48395
# [75]	validation_0-mlogloss:0.48282	validation_1-mlogloss:0.48370
# [76]	validation_0-mlogloss:0.48276	validation_1-mlogloss:0.48364
# [77]	validation_0-mlogloss:0.48174	validation_1-mlogloss:0.48259
# [78]	validation_0-mlogloss:0.48121	validation_1-mlogloss:0.48206
# [79]	validation_0-mlogloss:0.48107	validation_1-mlogloss:0.48195
# [80]	validation_0-mlogloss:0.48099	validation_1-mlogloss:0.48191
# [81]	validation_0-mlogloss:0.48056	validation_1-mlogloss:0.48151
# [82]	validation_0-mlogloss:0.48034	validation_1-mlogloss:0.48128
# [83]	validation_0-mlogloss:0.48025	validation_1-mlogloss:0.48121
# [84]	validation_0-mlogloss:0.47920	validation_1-mlogloss:0.48009
# [85]	validation_0-mlogloss:0.47819	validation_1-mlogloss:0.47914
# [86]	validation_0-mlogloss:0.47794	validation_1-mlogloss:0.47891
# [87]	validation_0-mlogloss:0.47782	validation_1-mlogloss:0.47880
# [88]	validation_0-mlogloss:0.47680	validation_1-mlogloss:0.47779
# [89]	validation_0-mlogloss:0.47672	validation_1-mlogloss:0.47773
# [90]	validation_0-mlogloss:0.47601	validation_1-mlogloss:0.47712
# [91]	validation_0-mlogloss:0.47573	validation_1-mlogloss:0.47689
# [92]	validation_0-mlogloss:0.47467	validation_1-mlogloss:0.47580
# [93]	validation_0-mlogloss:0.47443	validation_1-mlogloss:0.47557
# [94]	validation_0-mlogloss:0.47440	validation_1-mlogloss:0.47556
# [95]	validation_0-mlogloss:0.47418	validation_1-mlogloss:0.47533
# [96]	validation_0-mlogloss:0.47331	validation_1-mlogloss:0.47438
# [97]	validation_0-mlogloss:0.47308	validation_1-mlogloss:0.47420
# [98]	validation_0-mlogloss:0.47303	validation_1-mlogloss:0.47416
# [99]	validation_0-mlogloss:0.47275	validation_1-mlogloss:0.47395
# [100]	validation_0-mlogloss:0.47261	validation_1-mlogloss:0.47380
# [101]	validation_0-mlogloss:0.47233	validation_1-mlogloss:0.47355
# [102]	validation_0-mlogloss:0.47151	validation_1-mlogloss:0.47270
# [103]	validation_0-mlogloss:0.47114	validation_1-mlogloss:0.47235
# [104]	validation_0-mlogloss:0.47088	validation_1-mlogloss:0.47213
# [105]	validation_0-mlogloss:0.47009	validation_1-mlogloss:0.47143
# [106]	validation_0-mlogloss:0.46986	validation_1-mlogloss:0.47122
# [107]	validation_0-mlogloss:0.46791	validation_1-mlogloss:0.46918
# [108]	validation_0-mlogloss:0.46743	validation_1-mlogloss:0.46872
# [109]	validation_0-mlogloss:0.46714	validation_1-mlogloss:0.46849
# [110]	validation_0-mlogloss:0.46701	validation_1-mlogloss:0.46838
# [111]	validation_0-mlogloss:0.46669	validation_1-mlogloss:0.46810
# [112]	validation_0-mlogloss:0.46663	validation_1-mlogloss:0.46804
# [113]	validation_0-mlogloss:0.46658	validation_1-mlogloss:0.46800
# [114]	validation_0-mlogloss:0.46630	validation_1-mlogloss:0.46772
# [115]	validation_0-mlogloss:0.46619	validation_1-mlogloss:0.46766
# [116]	validation_0-mlogloss:0.46609	validation_1-mlogloss:0.46755
# [117]	validation_0-mlogloss:0.46606	validation_1-mlogloss:0.46752
# [118]	validation_0-mlogloss:0.46522	validation_1-mlogloss:0.46659
# [119]	validation_0-mlogloss:0.46495	validation_1-mlogloss:0.46638
# [120]	validation_0-mlogloss:0.46460	validation_1-mlogloss:0.46606
# [121]	validation_0-mlogloss:0.46418	validation_1-mlogloss:0.46570
# [122]	validation_0-mlogloss:0.46393	validation_1-mlogloss:0.46548
# [123]	validation_0-mlogloss:0.46381	validation_1-mlogloss:0.46540
# [124]	validation_0-mlogloss:0.46257	validation_1-mlogloss:0.46413
# [125]	validation_0-mlogloss:0.46227	validation_1-mlogloss:0.46383
# [126]	validation_0-mlogloss:0.46181	validation_1-mlogloss:0.46337
# [127]	validation_0-mlogloss:0.46169	validation_1-mlogloss:0.46329
# [128]	validation_0-mlogloss:0.46162	validation_1-mlogloss:0.46322
# [129]	validation_0-mlogloss:0.46148	validation_1-mlogloss:0.46308
# [130]	validation_0-mlogloss:0.46135	validation_1-mlogloss:0.46298
# [131]	validation_0-mlogloss:0.46086	validation_1-mlogloss:0.46251
# [132]	validation_0-mlogloss:0.46069	validation_1-mlogloss:0.46236
# [133]	validation_0-mlogloss:0.46063	validation_1-mlogloss:0.46231
# [134]	validation_0-mlogloss:0.46018	validation_1-mlogloss:0.46180
# [135]	validation_0-mlogloss:0.46010	validation_1-mlogloss:0.46174
# [136]	validation_0-mlogloss:0.45925	validation_1-mlogloss:0.46088
# [137]	validation_0-mlogloss:0.45902	validation_1-mlogloss:0.46064
# [138]	validation_0-mlogloss:0.45845	validation_1-mlogloss:0.46006
# [139]	validation_0-mlogloss:0.45843	validation_1-mlogloss:0.46005
# [140]	validation_0-mlogloss:0.45822	validation_1-mlogloss:0.45988
# [141]	validation_0-mlogloss:0.45810	validation_1-mlogloss:0.45979
# [142]	validation_0-mlogloss:0.45802	validation_1-mlogloss:0.45972
# [143]	validation_0-mlogloss:0.45800	validation_1-mlogloss:0.45970
# [144]	validation_0-mlogloss:0.45797	validation_1-mlogloss:0.45968
# [145]	validation_0-mlogloss:0.45795	validation_1-mlogloss:0.45968
# [146]	validation_0-mlogloss:0.45787	validation_1-mlogloss:0.45959
# [147]	validation_0-mlogloss:0.45771	validation_1-mlogloss:0.45945
# [148]	validation_0-mlogloss:0.45742	validation_1-mlogloss:0.45913
# [149]	validation_0-mlogloss:0.45716	validation_1-mlogloss:0.45883
# [150]	validation_0-mlogloss:0.45702	validation_1-mlogloss:0.45874
# [151]	validation_0-mlogloss:0.45684	validation_1-mlogloss:0.45860
# [152]	validation_0-mlogloss:0.45682	validation_1-mlogloss:0.45860
# [153]	validation_0-mlogloss:0.45677	validation_1-mlogloss:0.45855
# [154]	validation_0-mlogloss:0.45666	validation_1-mlogloss:0.45847
# [155]	validation_0-mlogloss:0.45653	validation_1-mlogloss:0.45838
# [156]	validation_0-mlogloss:0.45638	validation_1-mlogloss:0.45824
# [157]	validation_0-mlogloss:0.45608	validation_1-mlogloss:0.45793
# [158]	validation_0-mlogloss:0.45605	validation_1-mlogloss:0.45790
# [159]	validation_0-mlogloss:0.45603	validation_1-mlogloss:0.45789
# [160]	validation_0-mlogloss:0.45590	validation_1-mlogloss:0.45779
# [161]	validation_0-mlogloss:0.45568	validation_1-mlogloss:0.45755
# [162]	validation_0-mlogloss:0.45563	validation_1-mlogloss:0.45753
# [163]	validation_0-mlogloss:0.45551	validation_1-mlogloss:0.45741
# [164]	validation_0-mlogloss:0.45533	validation_1-mlogloss:0.45722
# [165]	validation_0-mlogloss:0.45472	validation_1-mlogloss:0.45662
# [166]	validation_0-mlogloss:0.45469	validation_1-mlogloss:0.45660
# [167]	validation_0-mlogloss:0.45468	validation_1-mlogloss:0.45660
# [168]	validation_0-mlogloss:0.45459	validation_1-mlogloss:0.45653
# [169]	validation_0-mlogloss:0.45457	validation_1-mlogloss:0.45652
# [170]	validation_0-mlogloss:0.45443	validation_1-mlogloss:0.45642
# [171]	validation_0-mlogloss:0.45442	validation_1-mlogloss:0.45643
# [172]	validation_0-mlogloss:0.45426	validation_1-mlogloss:0.45628
# [173]	validation_0-mlogloss:0.45424	validation_1-mlogloss:0.45627
# [174]	validation_0-mlogloss:0.45419	validation_1-mlogloss:0.45625
# [175]	validation_0-mlogloss:0.45413	validation_1-mlogloss:0.45618
# [176]	validation_0-mlogloss:0.45404	validation_1-mlogloss:0.45613
# [177]	validation_0-mlogloss:0.45402	validation_1-mlogloss:0.45612
# [178]	validation_0-mlogloss:0.45388	validation_1-mlogloss:0.45596
# [179]	validation_0-mlogloss:0.45376	validation_1-mlogloss:0.45585
# [180]	validation_0-mlogloss:0.45371	validation_1-mlogloss:0.45582
# [181]	validation_0-mlogloss:0.45351	validation_1-mlogloss:0.45564
# [182]	validation_0-mlogloss:0.45337	validation_1-mlogloss:0.45548
# [183]	validation_0-mlogloss:0.45333	validation_1-mlogloss:0.45546
# [184]	validation_0-mlogloss:0.45317	validation_1-mlogloss:0.45532
# [185]	validation_0-mlogloss:0.45316	validation_1-mlogloss:0.45532
# [186]	validation_0-mlogloss:0.45313	validation_1-mlogloss:0.45530
# [187]	validation_0-mlogloss:0.45296	validation_1-mlogloss:0.45515
# [188]	validation_0-mlogloss:0.45286	validation_1-mlogloss:0.45507
# [189]	validation_0-mlogloss:0.45282	validation_1-mlogloss:0.45502
# [190]	validation_0-mlogloss:0.45273	validation_1-mlogloss:0.45495
# [191]	validation_0-mlogloss:0.45264	validation_1-mlogloss:0.45487
# [192]	validation_0-mlogloss:0.45259	validation_1-mlogloss:0.45483
# [193]	validation_0-mlogloss:0.45254	validation_1-mlogloss:0.45480
# [194]	validation_0-mlogloss:0.45251	validation_1-mlogloss:0.45478
# [195]	validation_0-mlogloss:0.45247	validation_1-mlogloss:0.45473
# [196]	validation_0-mlogloss:0.45246	validation_1-mlogloss:0.45471
# [197]	validation_0-mlogloss:0.45232	validation_1-mlogloss:0.45461
# [198]	validation_0-mlogloss:0.45231	validation_1-mlogloss:0.45460
# [199]	validation_0-mlogloss:0.45227	validation_1-mlogloss:0.45457
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None, colsample_bytree=0,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
xgb_basic=xgb.XGBClassifier(n_estimators =180) 
evals_result = {}
xgb_basic.fit(X_train[features],y_train,
             eval_set = [( X_train, y_train), ( X_test, y_test)])
# Out:
# [0]	validation_0-mlogloss:0.87346	validation_1-mlogloss:0.87372
# [1]	validation_0-mlogloss:0.74192	validation_1-mlogloss:0.74242
# [2]	validation_0-mlogloss:0.65647	validation_1-mlogloss:0.65729
# [3]	validation_0-mlogloss:0.59771	validation_1-mlogloss:0.59889
# [4]	validation_0-mlogloss:0.55684	validation_1-mlogloss:0.55859
# [5]	validation_0-mlogloss:0.52746	validation_1-mlogloss:0.52962
# [6]	validation_0-mlogloss:0.50499	validation_1-mlogloss:0.50765
# [7]	validation_0-mlogloss:0.48800	validation_1-mlogloss:0.49096
# [8]	validation_0-mlogloss:0.47467	validation_1-mlogloss:0.47789
# [9]	validation_0-mlogloss:0.46436	validation_1-mlogloss:0.46802
# [10]	validation_0-mlogloss:0.45625	validation_1-mlogloss:0.46016
# [11]	validation_0-mlogloss:0.44917	validation_1-mlogloss:0.45346
# [12]	validation_0-mlogloss:0.44387	validation_1-mlogloss:0.44859
# [13]	validation_0-mlogloss:0.43898	validation_1-mlogloss:0.44408
# [14]	validation_0-mlogloss:0.43509	validation_1-mlogloss:0.44052
# [15]	validation_0-mlogloss:0.43185	validation_1-mlogloss:0.43766
# [16]	validation_0-mlogloss:0.42744	validation_1-mlogloss:0.43360
# [17]	validation_0-mlogloss:0.42542	validation_1-mlogloss:0.43197
# [18]	validation_0-mlogloss:0.42276	validation_1-mlogloss:0.42969
# [19]	validation_0-mlogloss:0.41998	validation_1-mlogloss:0.42728
# [20]	validation_0-mlogloss:0.41824	validation_1-mlogloss:0.42586
# [21]	validation_0-mlogloss:0.41620	validation_1-mlogloss:0.42411
# [22]	validation_0-mlogloss:0.41447	validation_1-mlogloss:0.42278
# [23]	validation_0-mlogloss:0.41265	validation_1-mlogloss:0.42132
# [24]	validation_0-mlogloss:0.41130	validation_1-mlogloss:0.42041
# [25]	validation_0-mlogloss:0.40962	validation_1-mlogloss:0.41910
# [26]	validation_0-mlogloss:0.40825	validation_1-mlogloss:0.41807
# [27]	validation_0-mlogloss:0.40630	validation_1-mlogloss:0.41634
# [28]	validation_0-mlogloss:0.40423	validation_1-mlogloss:0.41454
# [29]	validation_0-mlogloss:0.40342	validation_1-mlogloss:0.41407
# [30]	validation_0-mlogloss:0.40255	validation_1-mlogloss:0.41365
# [31]	validation_0-mlogloss:0.40120	validation_1-mlogloss:0.41264
# [32]	validation_0-mlogloss:0.39930	validation_1-mlogloss:0.41104
# [33]	validation_0-mlogloss:0.39820	validation_1-mlogloss:0.41042
# [34]	validation_0-mlogloss:0.39685	validation_1-mlogloss:0.40951
# [35]	validation_0-mlogloss:0.39598	validation_1-mlogloss:0.40901
# [36]	validation_0-mlogloss:0.39501	validation_1-mlogloss:0.40840
# [37]	validation_0-mlogloss:0.39390	validation_1-mlogloss:0.40749
# [38]	validation_0-mlogloss:0.39335	validation_1-mlogloss:0.40726
# [39]	validation_0-mlogloss:0.39255	validation_1-mlogloss:0.40681
# [40]	validation_0-mlogloss:0.39140	validation_1-mlogloss:0.40598
# [41]	validation_0-mlogloss:0.39028	validation_1-mlogloss:0.40524
# [42]	validation_0-mlogloss:0.38959	validation_1-mlogloss:0.40499
# [43]	validation_0-mlogloss:0.38861	validation_1-mlogloss:0.40439
# [44]	validation_0-mlogloss:0.38809	validation_1-mlogloss:0.40422
# [45]	validation_0-mlogloss:0.38172	validation_1-mlogloss:0.39817
# [46]	validation_0-mlogloss:0.38099	validation_1-mlogloss:0.39773
# [47]	validation_0-mlogloss:0.38067	validation_1-mlogloss:0.39761
# [48]	validation_0-mlogloss:0.37986	validation_1-mlogloss:0.39707
# [49]	validation_0-mlogloss:0.37967	validation_1-mlogloss:0.39702
# [50]	validation_0-mlogloss:0.37855	validation_1-mlogloss:0.39628
# [51]	validation_0-mlogloss:0.37643	validation_1-mlogloss:0.39453
# [52]	validation_0-mlogloss:0.37361	validation_1-mlogloss:0.39206
# [53]	validation_0-mlogloss:0.37142	validation_1-mlogloss:0.39034
# [54]	validation_0-mlogloss:0.37033	validation_1-mlogloss:0.38972
# [55]	validation_0-mlogloss:0.36993	validation_1-mlogloss:0.38964
# [56]	validation_0-mlogloss:0.36956	validation_1-mlogloss:0.38950
# [57]	validation_0-mlogloss:0.36897	validation_1-mlogloss:0.38919
# [58]	validation_0-mlogloss:0.36825	validation_1-mlogloss:0.38889
# [59]	validation_0-mlogloss:0.36791	validation_1-mlogloss:0.38884
# [60]	validation_0-mlogloss:0.36695	validation_1-mlogloss:0.38817
# [61]	validation_0-mlogloss:0.36664	validation_1-mlogloss:0.38817
# [62]	validation_0-mlogloss:0.36637	validation_1-mlogloss:0.38815
# [63]	validation_0-mlogloss:0.36571	validation_1-mlogloss:0.38770
# [64]	validation_0-mlogloss:0.36539	validation_1-mlogloss:0.38760
# [65]	validation_0-mlogloss:0.36487	validation_1-mlogloss:0.38741
# [66]	validation_0-mlogloss:0.36172	validation_1-mlogloss:0.38457
# [67]	validation_0-mlogloss:0.36099	validation_1-mlogloss:0.38423
# [68]	validation_0-mlogloss:0.35733	validation_1-mlogloss:0.38095
# [69]	validation_0-mlogloss:0.35687	validation_1-mlogloss:0.38082
# [70]	validation_0-mlogloss:0.35653	validation_1-mlogloss:0.38072
# [71]	validation_0-mlogloss:0.35599	validation_1-mlogloss:0.38057
# [72]	validation_0-mlogloss:0.35401	validation_1-mlogloss:0.37878
# [73]	validation_0-mlogloss:0.35350	validation_1-mlogloss:0.37854
# [74]	validation_0-mlogloss:0.35318	validation_1-mlogloss:0.37843
# [75]	validation_0-mlogloss:0.35129	validation_1-mlogloss:0.37679
# [76]	validation_0-mlogloss:0.35081	validation_1-mlogloss:0.37659
# [77]	validation_0-mlogloss:0.34842	validation_1-mlogloss:0.37451
# [78]	validation_0-mlogloss:0.34783	validation_1-mlogloss:0.37422
# [79]	validation_0-mlogloss:0.34714	validation_1-mlogloss:0.37389
# [80]	validation_0-mlogloss:0.34677	validation_1-mlogloss:0.37375
# [81]	validation_0-mlogloss:0.34499	validation_1-mlogloss:0.37225
# [82]	validation_0-mlogloss:0.34334	validation_1-mlogloss:0.37080
# [83]	validation_0-mlogloss:0.34278	validation_1-mlogloss:0.37062
# [84]	validation_0-mlogloss:0.34228	validation_1-mlogloss:0.37034
# [85]	validation_0-mlogloss:0.34200	validation_1-mlogloss:0.37025
# [86]	validation_0-mlogloss:0.34164	validation_1-mlogloss:0.37019
# [87]	validation_0-mlogloss:0.34104	validation_1-mlogloss:0.36986
# [88]	validation_0-mlogloss:0.34062	validation_1-mlogloss:0.36982
# [89]	validation_0-mlogloss:0.34045	validation_1-mlogloss:0.36983
# [90]	validation_0-mlogloss:0.34006	validation_1-mlogloss:0.36962
# [91]	validation_0-mlogloss:0.33885	validation_1-mlogloss:0.36868
# [92]	validation_0-mlogloss:0.33788	validation_1-mlogloss:0.36807
# [93]	validation_0-mlogloss:0.33727	validation_1-mlogloss:0.36759
# [94]	validation_0-mlogloss:0.33589	validation_1-mlogloss:0.36636
# [95]	validation_0-mlogloss:0.33573	validation_1-mlogloss:0.36635
# [96]	validation_0-mlogloss:0.33499	validation_1-mlogloss:0.36584
# [97]	validation_0-mlogloss:0.33470	validation_1-mlogloss:0.36583
# [98]	validation_0-mlogloss:0.33407	validation_1-mlogloss:0.36552
# [99]	validation_0-mlogloss:0.33025	validation_1-mlogloss:0.36193
# [100]	validation_0-mlogloss:0.32981	validation_1-mlogloss:0.36182
# [101]	validation_0-mlogloss:0.32958	validation_1-mlogloss:0.36179
# [102]	validation_0-mlogloss:0.32938	validation_1-mlogloss:0.36178
# [103]	validation_0-mlogloss:0.32915	validation_1-mlogloss:0.36179
# [104]	validation_0-mlogloss:0.32895	validation_1-mlogloss:0.36179
# [105]	validation_0-mlogloss:0.32878	validation_1-mlogloss:0.36178
# [106]	validation_0-mlogloss:0.32852	validation_1-mlogloss:0.36161
# [107]	validation_0-mlogloss:0.32831	validation_1-mlogloss:0.36163
# [108]	validation_0-mlogloss:0.32801	validation_1-mlogloss:0.36161
# [109]	validation_0-mlogloss:0.32715	validation_1-mlogloss:0.36101
# [110]	validation_0-mlogloss:0.32656	validation_1-mlogloss:0.36071
# [111]	validation_0-mlogloss:0.32567	validation_1-mlogloss:0.36021
# [112]	validation_0-mlogloss:0.32548	validation_1-mlogloss:0.36016
# [113]	validation_0-mlogloss:0.32485	validation_1-mlogloss:0.35977
# [114]	validation_0-mlogloss:0.32422	validation_1-mlogloss:0.35933
# [115]	validation_0-mlogloss:0.32265	validation_1-mlogloss:0.35810
# [116]	validation_0-mlogloss:0.32234	validation_1-mlogloss:0.35810
# [117]	validation_0-mlogloss:0.32202	validation_1-mlogloss:0.35806
# [118]	validation_0-mlogloss:0.32159	validation_1-mlogloss:0.35796
# [119]	validation_0-mlogloss:0.32123	validation_1-mlogloss:0.35777
# [120]	validation_0-mlogloss:0.32069	validation_1-mlogloss:0.35751
# [121]	validation_0-mlogloss:0.32042	validation_1-mlogloss:0.35751
# [122]	validation_0-mlogloss:0.32023	validation_1-mlogloss:0.35753
# [123]	validation_0-mlogloss:0.32001	validation_1-mlogloss:0.35749
# [124]	validation_0-mlogloss:0.31983	validation_1-mlogloss:0.35750
# [125]	validation_0-mlogloss:0.31942	validation_1-mlogloss:0.35747
# [126]	validation_0-mlogloss:0.31920	validation_1-mlogloss:0.35741
# [127]	validation_0-mlogloss:0.31902	validation_1-mlogloss:0.35738
# [128]	validation_0-mlogloss:0.31876	validation_1-mlogloss:0.35738
# [129]	validation_0-mlogloss:0.31833	validation_1-mlogloss:0.35722
# [130]	validation_0-mlogloss:0.31763	validation_1-mlogloss:0.35682
# [131]	validation_0-mlogloss:0.31730	validation_1-mlogloss:0.35682
# [132]	validation_0-mlogloss:0.31716	validation_1-mlogloss:0.35682
# [133]	validation_0-mlogloss:0.31694	validation_1-mlogloss:0.35682
# [134]	validation_0-mlogloss:0.31649	validation_1-mlogloss:0.35660
# [135]	validation_0-mlogloss:0.31599	validation_1-mlogloss:0.35638
# [136]	validation_0-mlogloss:0.31572	validation_1-mlogloss:0.35638
# [137]	validation_0-mlogloss:0.31540	validation_1-mlogloss:0.35636
# [138]	validation_0-mlogloss:0.31516	validation_1-mlogloss:0.35633
# [139]	validation_0-mlogloss:0.31492	validation_1-mlogloss:0.35631
# [140]	validation_0-mlogloss:0.31461	validation_1-mlogloss:0.35631
# [141]	validation_0-mlogloss:0.31429	validation_1-mlogloss:0.35631
# [142]	validation_0-mlogloss:0.31366	validation_1-mlogloss:0.35590
# [143]	validation_0-mlogloss:0.31324	validation_1-mlogloss:0.35573
# [144]	validation_0-mlogloss:0.31270	validation_1-mlogloss:0.35544
# [145]	validation_0-mlogloss:0.31244	validation_1-mlogloss:0.35542
# [146]	validation_0-mlogloss:0.30999	validation_1-mlogloss:0.35293
# [147]	validation_0-mlogloss:0.30968	validation_1-mlogloss:0.35290
# [148]	validation_0-mlogloss:0.30937	validation_1-mlogloss:0.35289
# [149]	validation_0-mlogloss:0.30873	validation_1-mlogloss:0.35254
# [150]	validation_0-mlogloss:0.30833	validation_1-mlogloss:0.35247
# [151]	validation_0-mlogloss:0.30813	validation_1-mlogloss:0.35246
# [152]	validation_0-mlogloss:0.30780	validation_1-mlogloss:0.35241
# [153]	validation_0-mlogloss:0.30768	validation_1-mlogloss:0.35242
# [154]	validation_0-mlogloss:0.30750	validation_1-mlogloss:0.35242
# [155]	validation_0-mlogloss:0.30737	validation_1-mlogloss:0.35240
# [156]	validation_0-mlogloss:0.30725	validation_1-mlogloss:0.35240
# [157]	validation_0-mlogloss:0.30716	validation_1-mlogloss:0.35243
# [158]	validation_0-mlogloss:0.30696	validation_1-mlogloss:0.35241
# [159]	validation_0-mlogloss:0.30662	validation_1-mlogloss:0.35239
# [160]	validation_0-mlogloss:0.30630	validation_1-mlogloss:0.35236
# [161]	validation_0-mlogloss:0.30586	validation_1-mlogloss:0.35223
# [162]	validation_0-mlogloss:0.30475	validation_1-mlogloss:0.35143
# [163]	validation_0-mlogloss:0.30445	validation_1-mlogloss:0.35139
# [164]	validation_0-mlogloss:0.30409	validation_1-mlogloss:0.35123
# [165]	validation_0-mlogloss:0.30384	validation_1-mlogloss:0.35123
# [166]	validation_0-mlogloss:0.30367	validation_1-mlogloss:0.35127
# [167]	validation_0-mlogloss:0.30355	validation_1-mlogloss:0.35127
# [168]	validation_0-mlogloss:0.30328	validation_1-mlogloss:0.35132
# [169]	validation_0-mlogloss:0.30309	validation_1-mlogloss:0.35135
# [170]	validation_0-mlogloss:0.30288	validation_1-mlogloss:0.35135
# [171]	validation_0-mlogloss:0.30284	validation_1-mlogloss:0.35137
# [172]	validation_0-mlogloss:0.30258	validation_1-mlogloss:0.35135
# [173]	validation_0-mlogloss:0.30232	validation_1-mlogloss:0.35125
# [174]	validation_0-mlogloss:0.30185	validation_1-mlogloss:0.35093
# [175]	validation_0-mlogloss:0.30154	validation_1-mlogloss:0.35088
# [176]	validation_0-mlogloss:0.30117	validation_1-mlogloss:0.35086
# [177]	validation_0-mlogloss:0.30092	validation_1-mlogloss:0.35083
# [178]	validation_0-mlogloss:0.30067	validation_1-mlogloss:0.35081
# [179]	validation_0-mlogloss:0.30054	validation_1-mlogloss:0.35083
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=180, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
pred_test = xgb_basic.predict(X_test)
accuracy_score(pred_test,y_test)

# %%
sns.set(font_scale = 1.5)
history  = xgb_model.evals_result()
history2  = xgb_basic.evals_result()
plt.plot(history['validation_0']['mlogloss'], label='train opt')
plt.plot(history['validation_1']['mlogloss'], label='val opt')
plt.plot(history2['validation_0']['mlogloss'], label='train basic')
plt.plot(history2['validation_1']['mlogloss'], label='val basic')
plt.ylabel('log loss')
plt.xlabel('epochs')
plt.title('XGB Training loss curve')
plt.legend()

# %%
sns.set(font_scale = 1.5)
history  = xgb_model2.evals_result()
history2  = xgb_basic.evals_result()
plt.plot(history['validation_0']['mlogloss'], label='train opt')
plt.plot(history['validation_1']['mlogloss'], label='val opt')
plt.plot(history2['validation_0']['mlogloss'], label='train basic')
plt.plot(history2['validation_1']['mlogloss'], label='val basic')
plt.ylabel('log loss')
plt.xlabel('epochs')
plt.title('BDT Training loss curve')
plt.legend()

# %%
plt.plot(history['validation_0']['mlogloss'], label='train')
plt.plot(history['validation_1']['mlogloss'], label='test')
plt.legend()

# %%
pred_val =  xgb_basic.predict(X_val)
cm = confusion_matrix(y_val, pred_val)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm_df = pd.DataFrame(cmn,
                     index = ['0','1','2'], 
                     columns = ['0','1','2'])
fig, ax = plt.subplots()
sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=list(cm_df), yticklabels=list(cm_df), vmax=1 )
plt.title('BDT Test Data Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted  Values')
plt.show(block=False)

# %%
pred_test = xgb_basic.predict(X_test)
accuracy_score(pred_test,y_test)

# %%
from sklearn.metrics import classification_report

target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y_val, pred_val ,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.89      0.81      0.85     39921
#      class 1       0.81      0.88      0.85     40040
#      class 2       0.89      0.90      0.90     24181
#
#     accuracy                           0.86    104142
#    macro avg       0.86      0.86      0.86    104142
# weighted avg       0.86      0.86      0.86    104142
